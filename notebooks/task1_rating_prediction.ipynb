# %%
# Install necessary libraries
# !pip install -q langchain-groq langchain pandas scikit-learn

import os
import json
import pandas as pd
import time
from sklearn.metrics import accuracy_score, classification_report
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

# --- CONFIGURATION ---
# Paste your Groq Key here (or use the one from your .env file)

# Initialize the LLM
llm = ChatGroq(
    temperature=0,
    model_name="llama-3.3-70b-versatile", # Changed from llama3-70b-8192 to a currently supported model
    api_key=os.environ["GROQ_API_KEY"]
)

print("Setup Complete! LLM is ready.")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Setup Complete! LLM is ready.

# %%
# --- OPTION A: GENERATE DUMMY DATA (For Instant Testing) ---
# data = [
#     {"text": "The food was absolutely wonderful, from preparation to presentation, very pleasing.", "stars": 5},
#     {"text": "Service was slow and the waiter was rude. I will never come back.", "stars": 1},
#     {"text": "It was okay. Not great, not terrible. Just average food.", "stars": 3},
#     {"text": "I loved the ambiance but the steak was overcooked.", "stars": 3},
#     {"text": "Best pizza in town! Highly recommended.", "stars": 5},
#     {"text": "Disgusting hygiene. Found a hair in my soup.", "stars": 1},
#     {"text": "Pretty good experience, but a bit pricey for the portion size.", "stars": 4},
#     {"text": "Terrible. Do not waste your money here.", "stars": 1},
#     {"text": "A hidden gem! The pasta is to die for.", "stars": 5},
#     {"text": "Mediocre at best. I've had better frozen dinners.", "stars": 2}
# ]
# df = pd.DataFrame(data)

# --- OPTION B: LOAD REAL YELP DATA 
df = pd.read_csv("../data/yelp.csv")

# Keep only required columns
df = df[["text", "stars"]]

# Sample 200 reviews as required
df = df.sample(200, random_state=42).reset_index(drop=True)

print(f"Loaded {len(df)} Yelp reviews")
display(df.head())
# Out:
# Loaded 200 Yelp reviews
#                                                 text  stars
# 0  We got here around midnight last Friday... the...      4
# 1  Brought a friend from Louisiana here.  She say...      5
# 2  Every friday, my dad and I eat here. We order ...      3
# 3  My husband and I were really, really disappoin...      1
# 4  Love this place!  Was in phoenix 3 weeks for w...      5

# %%
# Define the Output Parser to ensure valid JSON
parser = JsonOutputParser()

# --- PROMPT 1: ZERO-SHOT (Direct) ---
prompt_1 = ChatPromptTemplate.from_messages([
    ("system", "You are a sentiment analysis AI. Return valid JSON only."),
    ("user", """
    Classify the sentiment of this Yelp review into a star rating (1-5).
    Review: "{text}"

    Output Format:
    {{
        "predicted_stars": <int>,
        "explanation": "<string>"
    }}
    """)
])

# --- PROMPT 2: FEW-SHOT (With Examples) ---
prompt_2 = ChatPromptTemplate.from_messages([
    ("system", "You are a sentiment analysis AI. Learn from the examples and classify the new review."),
    ("user", """
    Examples:
    Review: "Worst place ever!" -> {{"predicted_stars": 1, "explanation": "Extreme negative sentiment."}}
    Review: "It was okay, nothing special." -> {{"predicted_stars": 3, "explanation": "Neutral sentiment."}}
    Review: "Absolutely loved it!" -> {{"predicted_stars": 5, "explanation": "Strong positive sentiment."}}

    Task:
    Review: "{text}"

    Return JSON only.
    """)
])

# --- PROMPT 3: CRITERIA-BASED (Chain of Thought Lite) ---
prompt_3 = ChatPromptTemplate.from_messages([
    ("system", "You are an expert critic. Analyze the review based on specific criteria."),
    ("user", """
    Review: "{text}"

    Analyze the review internally based on sentiment polarity, intensity, and specificity.
    Do not reveal step-by-step reasoning.

    Based on this analysis, assign a rating from 1 to 5.

    Output JSON:
    {{
        "predicted_stars": <int>,
        "explanation": "<Brief reasoning based on analysis>"
    }}
    """)
])

# Dictionary to store our chains
strategies = {
    "Zero-Shot": prompt_1 | llm | parser,
    "Few-Shot": prompt_2 | llm | parser,
    "Criteria-Based": prompt_3 | llm | parser
}

print("Strategies defined.")
# Out:
# Strategies defined.

# %%
results = []
summary_results = []

print("Starting evaluation... this might take a minute.")

for strategy_name, chain in strategies.items():
    print(f"Running strategy: {strategy_name}...")

    correct_predictions = 0
    valid_json_count = 0

    for index, row in df.iterrows():
        try:
            # Invoke LLM
            output = chain.invoke({"text": row['text']})

            time.sleep(0.25)

            # Check JSON Validity
            if "predicted_stars" in output and "explanation" in output:
                valid_json_count += 1

            # Check Accuracy
            predicted = int(output['predicted_stars'])
            actual = int(row['stars'])

            if predicted == actual:
                correct_predictions += 1

            # Store detail for review
            results.append({
                "Strategy": strategy_name,
                "Review": row['text'][:50] + "...",
                "Actual": actual,
                "Predicted": predicted,
                "Explanation": output['explanation']
            })

        except Exception as e:
            print(f"Error in {strategy_name} at index {index}: {e}")

    # Calculate Metrics for this strategy
    accuracy = (correct_predictions / len(df)) * 100
    json_validity_rate = (valid_json_count / len(df)) * 100
    print(
    f"--> {strategy_name} Accuracy: {accuracy:.2f}% | "
    f"JSON Validity: {json_validity_rate:.2f}%"
    )
    summary_results.append({
    "Strategy": strategy_name,
    "Accuracy (%)": round(accuracy, 2),
    "JSON Validity (%)": round(json_validity_rate, 2)
    })

# Create Comparison Table
results_df = pd.DataFrame(results)
print("\n--- FINAL COMPARISON ---")
display(results_df.groupby("Strategy").apply(lambda x: (x['Actual'] == x['Predicted']).mean() * 100).reset_index(name="Accuracy %"))
print("\n--- STRATEGY COMPARISON (REQUIRED METRICS) ---")
summary_df = pd.DataFrame(summary_results)
display(summary_df)


# Show detailed samples
display(results_df.head())
# Out:
# Starting evaluation... this might take a minute.
# Running strategy: Zero-Shot...
# Error in Zero-Shot at index 199: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99748, Requested 410. Please try again in 2m16.512s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# --> Zero-Shot Accuracy: 58.00% | JSON Validity: 99.50%
# Running strategy: Few-Shot...
# Error in Few-Shot at index 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 100000, Requested 182. Please try again in 2m37.248s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 100000, Requested 191. Please try again in 2m45.024s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 3: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 100000, Requested 417. Please try again in 6m0.288s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 4: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 100000, Requested 202. Please try again in 2m54.528s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 5: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 100000, Requested 387. Please try again in 5m34.368s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 6: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 258. Please try again in 3m42.047999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 7: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 171. Please try again in 2m26.88s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 8: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 192. Please try again in 2m45.024s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 9: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 211. Please try again in 3m1.44s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 10: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 207. Please try again in 2m57.984s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 11: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 244. Please try again in 3m29.952s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 12: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 161. Please try again in 2m18.24s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 13: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99999, Requested 529. Please try again in 7m36.192s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 14: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 201. Please try again in 2m51.936s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 15: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 243. Please try again in 3m28.224s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 16: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 354. Please try again in 5m4.128s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 17: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 229. Please try again in 3m16.128s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 18: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 167. Please try again in 2m22.56s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 19: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 303. Please try again in 4m20.064s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 20: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 283. Please try again in 4m2.784s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 21: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99998, Requested 439. Please try again in 6m17.568s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 22: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 244. Please try again in 3m28.224s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 23: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 350. Please try again in 4m59.808s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 24: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 406. Please try again in 5m48.191999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 25: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 263. Please try again in 3m44.64s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 26: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 160. Please try again in 2m15.648s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 27: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 548. Please try again in 7m50.88s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 28: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 212. Please try again in 3m0.576s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 29: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99997, Requested 394. Please try again in 5m37.824s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 30: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 334. Please try again in 4m45.12s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 31: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 870. Please try again in 12m28.223999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 32: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 226. Please try again in 3m11.808s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 33: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 534. Please try again in 7m37.92s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 34: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 288. Please try again in 4m5.376s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 35: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 303. Please try again in 4m18.336s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 36: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 197. Please try again in 2m46.752s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 37: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99996, Requested 508. Please try again in 7m15.456s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 38: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 297. Please try again in 4m12.287999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 39: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 164. Please try again in 2m17.376s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 40: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 467. Please try again in 6m39.168s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 41: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 449. Please try again in 6m23.616s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 42: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 473. Please try again in 6m44.352s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 43: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 1293. Please try again in 18m32.832s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 44: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 290. Please try again in 4m6.24s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 45: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99995, Requested 256. Please try again in 3m36.864s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 46: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 336. Please try again in 4m45.12s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 47: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 268. Please try again in 3m46.368s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 48: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 644. Please try again in 9m11.232s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 49: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 371. Please try again in 5m15.36s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 50: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 265. Please try again in 3m43.775999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 51: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 208. Please try again in 2m54.528s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 52: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 318. Please try again in 4m29.567999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 53: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99994, Requested 236. Please try again in 3m18.72s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 54: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 500. Please try again in 7m5.952s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 55: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 241. Please try again in 3m22.176s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 56: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 247. Please try again in 3m27.36s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 57: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 197. Please try again in 2m44.16s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 58: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 211. Please try again in 2m56.256s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 59: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 293. Please try again in 4m7.104s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 60: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 256. Please try again in 3m35.136s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 61: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 194. Please try again in 2m41.567999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 62: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99993, Requested 326. Please try again in 4m35.616s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 63: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 261. Please try again in 3m38.592s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 64: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 484. Please try again in 6m51.264s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 65: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 319. Please try again in 4m28.704s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 66: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 269. Please try again in 3m45.504s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 67: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 209. Please try again in 2m53.664s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 68: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 174. Please try again in 2m23.424s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 69: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 346. Please try again in 4m52.032s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 70: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99992, Requested 249. Please try again in 3m28.224s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 71: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 225. Please try again in 3m6.624s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 72: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 420. Please try again in 5m55.104s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 73: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 282. Please try again in 3m55.872s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 74: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 231. Please try again in 3m11.808s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 75: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 232. Please try again in 3m12.672s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 76: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 224. Please try again in 3m5.76s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 77: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 173. Please try again in 2m21.696s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 78: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99991, Requested 358. Please try again in 5m1.536s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 79: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 426. Please try again in 5m59.424s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 80: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 176. Please try again in 2m23.424s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 81: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 207. Please try again in 2m50.208s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 82: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 890. Please try again in 12m40.32s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 83: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 368. Please try again in 5m9.312s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 84: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 351. Please try again in 4m54.623999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 85: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 268. Please try again in 3m42.911999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 86: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99990, Requested 266. Please try again in 3m41.184s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 87: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 224. Please try again in 3m4.031999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 88: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 169. Please try again in 2m16.512s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 89: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 223. Please try again in 3m3.168s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 90: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 211. Please try again in 2m52.8s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 91: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 278. Please try again in 3m50.688s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 92: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 160. Please try again in 2m8.735999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 93: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 562. Please try again in 7m56.064s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 94: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99989, Requested 262. Please try again in 3m36.864s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 95: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 212. Please try again in 2m52.8s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 96: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 297. Please try again in 4m6.24s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 97: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 190. Please try again in 2m33.792s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 98: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 307. Please try again in 4m14.88s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 99: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 281. Please try again in 3m52.416s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 100: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 405. Please try again in 5m39.552s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 101: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99988, Requested 329. Please try again in 4m33.888s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 102: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 269. Please try again in 3m41.184s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 103: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 590. Please try again in 8m18.528s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 104: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 492. Please try again in 6m53.856s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 105: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 383. Please try again in 5m19.68s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 106: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 272. Please try again in 3m43.775999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Few-Shot at index 107: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99987, Requested 310. Please try again in 4m16.608s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ...
# Error in Criteria-Based at index 169: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 519. Please try again in 6m48.671999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 170: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 200. Please try again in 2m13.055999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 171: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 554. Please try again in 7m18.912s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 172: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 421. Please try again in 5m24s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 173: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 289. Please try again in 3m29.952s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 174: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 223. Please try again in 2m32.928s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 175: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 504. Please try again in 6m35.712s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 176: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 156. Please try again in 1m35.04s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 177: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 350. Please try again in 4m22.656s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 178: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99954, Requested 310. Please try again in 3m48.096s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 179: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 189. Please try again in 2m2.688s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 180: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 158. Please try again in 1m35.904s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 181: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 393. Please try again in 4m58.944s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 182: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 338. Please try again in 4m11.423999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 183: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 279. Please try again in 3m20.448s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 184: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 281. Please try again in 3m22.176s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 185: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 158. Please try again in 1m35.904s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 186: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 186. Please try again in 2m0.095999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 187: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99953, Requested 240. Please try again in 2m46.752s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 188: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 185. Please try again in 1m58.368s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 189: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 289. Please try again in 3m28.224s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 190: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 366. Please try again in 4m34.752s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 191: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 172. Please try again in 1m47.136s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 192: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 158. Please try again in 1m35.04s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 193: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 215. Please try again in 2m24.288s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 194: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 153. Please try again in 1m30.72s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 195: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 187. Please try again in 2m0.095999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 196: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99952, Requested 283. Please try again in 3m23.04s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 197: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99951, Requested 370. Please try again in 4m37.344s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 198: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99951, Requested 173. Please try again in 1m47.136s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Error in Criteria-Based at index 199: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01kcgtwyf0fxqb9k22t4tycx4n` service tier `on_demand` on tokens per day (TPD): Limit 100000, Used 99951, Requested 440. Please try again in 5m37.824s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# --> Criteria-Based Accuracy: 0.00% | JSON Validity: 0.00%
#
# --- FINAL COMPARISON ---
# C:\Users\pasta\AppData\Local\Temp\ipykernel_11176\2542006163.py:58: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   display(results_df.groupby("Strategy").apply(lambda x: (x['Actual'] == x['Predicted']).mean() * 100).reset_index(name="Accuracy %"))
#     Strategy  Accuracy %
# 0   Few-Shot  100.000000
# 1  Zero-Shot   58.291457
# --- STRATEGY COMPARISON (REQUIRED METRICS) ---
#          Strategy  Accuracy (%)  JSON Validity (%)
# 0       Zero-Shot          58.0               99.5
# 1        Few-Shot           0.5                0.5
# 2  Criteria-Based           0.0                0.0
#     Strategy                                             Review  Actual  \
# 0  Zero-Shot  We got here around midnight last Friday... the...       4
# 1  Zero-Shot  Brought a friend from Louisiana here.  She say...       5
# 2  Zero-Shot  Every friday, my dad and I eat here. We order ...       3
# 3  Zero-Shot  My husband and I were really, really disappoin...       1
# 4  Zero-Shot  Love this place!  Was in phoenix 3 weeks for w...       5
#
#    Predicted                                        Explanation
# 0          4  The reviewer had a positive experience with th...
# 1          5  The reviewer's friend, who is from Louisiana, ...
# 2          4  The reviewer mentions that they are regular cu...
# 3          1  The reviewer expresses extreme disappointment ...
# 4          5  The reviewer uses extremely positive language,...
